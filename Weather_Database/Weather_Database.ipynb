# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a new set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | iquique
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | novokruchininskiy
# Processing Record 7 of Set 1 | sorong
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | noumea
# Processing Record 10 of Set 1 | pestravka
# Processing Record 11 of Set 1 | varzea da palma
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | lhuntshi
# City not found. Skipping...
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | hualmay
# Processing Record 20 of Set 1 | wageningen
# Processing Record 21 of Set 1 | borama
# City not found. Skipping...
# Processing Record 22 of Set 1 | muros
# Processing Record 23 of Set 1 | vila velha
# Processing Record 24 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | chumikan
# Processing Record 27 of Set 1 | davila
# Processing Record 28 of Set 1 | komsomolskiy
# Processing Record 29 of Set 1 | sao filipe
# Processing Record 30 of Set 1 | panguna
# Processing Record 31 of Set 1 | wanning
# Processing Record 32 of Set 1 | priyutnoye
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | severo-yeniseyskiy
# Processing Record 36 of Set 1 | abnub
# Processing Record 37 of Set 1 | victor harbor
# Processing Record 38 of Set 1 | meulaboh
# Processing Record 39 of Set 1 | lagoa
# Processing Record 40 of Set 1 | batagay-alyta
# Processing Record 41 of Set 1 | muli
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | mnogovershinnyy
# Processing Record 44 of Set 1 | pisco
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | lucapa
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | bethel
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | kaeo
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | kirovskiy
# Processing Record 4 of Set 2 | constitucion
# Processing Record 5 of Set 2 | erenhot
# Processing Record 6 of Set 2 | vao
# Processing Record 7 of Set 2 | yulara
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 2 | chimbote
# Processing Record 12 of Set 2 | deta
# Processing Record 13 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | vostok
# Processing Record 20 of Set 2 | klaksvik
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | lorengau
# Processing Record 23 of Set 2 | buta
# Processing Record 24 of Set 2 | butaritari
# Processing Record 25 of Set 2 | kurchum
# Processing Record 26 of Set 2 | sieradz
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | bani
# Processing Record 29 of Set 2 | gushikawa
# Processing Record 30 of Set 2 | coahuayana
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | leningradskiy
# Processing Record 33 of Set 2 | faya
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | pevek
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | richards bay
# Processing Record 38 of Set 2 | maceio
# Processing Record 39 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | macau
# Processing Record 42 of Set 2 | yar-sale
# Processing Record 43 of Set 2 | tarko-sale
# Processing Record 44 of Set 2 | sao felix do xingu
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | ust-nera
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | saint anthony
# Processing Record 49 of Set 2 | srednekolymsk
# Processing Record 50 of Set 2 | goundam
# Processing Record 1 of Set 3 | dole
# Processing Record 2 of Set 3 | sambava
# Processing Record 3 of Set 3 | sitka
# Processing Record 4 of Set 3 | mafinga
# Processing Record 5 of Set 3 | irbit
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 3 | samarai
# Processing Record 9 of Set 3 | flin flon
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 3 | thompson
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 3 | busselton
# Processing Record 16 of Set 3 | kavieng
# Processing Record 17 of Set 3 | lasa
# Processing Record 18 of Set 3 | qiongshan
# Processing Record 19 of Set 3 | shenjiamen
# Processing Record 20 of Set 3 | san carlos de bariloche
# Processing Record 21 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 3 | comodoro rivadavia
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | tura
# Processing Record 25 of Set 3 | truro
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | sivaki
# Processing Record 28 of Set 3 | sovetskaya gavan
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | shira
# Processing Record 31 of Set 3 | bluff
# Processing Record 32 of Set 3 | moose factory
# Processing Record 33 of Set 3 | bay roberts
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 3 | buraydah
# Processing Record 37 of Set 3 | kruisfontein
# Processing Record 38 of Set 3 | tessalit
# Processing Record 39 of Set 3 | tuatapere
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | airai
# Processing Record 42 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 3 | vestbygda
# City not found. Skipping...
# Processing Record 44 of Set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 45 of Set 3 | fortuna
# Processing Record 46 of Set 3 | tambacounda
# Processing Record 47 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 3 | port lincoln
# Processing Record 49 of Set 3 | san-pedro
# Processing Record 50 of Set 3 | albany
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | purbalingga
# Processing Record 5 of Set 4 | cape town
# Processing Record 6 of Set 4 | palaia fokaia
# Processing Record 7 of Set 4 | shellbrook
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | vanimo
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | saskylakh
# Processing Record 12 of Set 4 | dien bien
# City not found. Skipping...
# Processing Record 13 of Set 4 | sayansk
# Processing Record 14 of Set 4 | santa barbara
# Processing Record 15 of Set 4 | barrow
# Processing Record 16 of Set 4 | antigonish
# Processing Record 17 of Set 4 | souillac
# Processing Record 18 of Set 4 | kentau
# Processing Record 19 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 4 | mutare
# Processing Record 21 of Set 4 | esperance
# Processing Record 22 of Set 4 | cangzhou
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | waiouru
# Processing Record 25 of Set 4 | berlevag
# Processing Record 26 of Set 4 | caravelas
# Processing Record 27 of Set 4 | havoysund
# Processing Record 28 of Set 4 | volkhov
# Processing Record 29 of Set 4 | smithers
# Processing Record 30 of Set 4 | krasnoselkup
# Processing Record 31 of Set 4 | kabale
# Processing Record 32 of Set 4 | kutum
# Processing Record 33 of Set 4 | hasaki
# Processing Record 34 of Set 4 | ambulu
# Processing Record 35 of Set 4 | east london
# Processing Record 36 of Set 4 | rio gallegos
# Processing Record 37 of Set 4 | altoona
# Processing Record 38 of Set 4 | broome
# Processing Record 39 of Set 4 | port hardy
# Processing Record 40 of Set 4 | new norfolk
# Processing Record 41 of Set 4 | katsina
# Processing Record 42 of Set 4 | honiara
# Processing Record 43 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 4 | sabha
# Processing Record 45 of Set 4 | tecoanapa
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 4 | nizhneangarsk
# Processing Record 48 of Set 4 | bac lieu
# Processing Record 49 of Set 4 | ayorou
# Processing Record 50 of Set 4 | irbeyskoye
# Processing Record 1 of Set 5 | emerald
# Processing Record 2 of Set 5 | naze
# Processing Record 3 of Set 5 | norman wells
# Processing Record 4 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 5 | klyuchi
# Processing Record 6 of Set 5 | dingle
# Processing Record 7 of Set 5 | kempsey
# Processing Record 8 of Set 5 | red bluff
# Processing Record 9 of Set 5 | taoudenni
# Processing Record 10 of Set 5 | nhamunda
# Processing Record 11 of Set 5 | high level
# Processing Record 12 of Set 5 | faanui
# Processing Record 13 of Set 5 | constantine
# Processing Record 14 of Set 5 | kara-tyube
# Processing Record 15 of Set 5 | asfi
# Processing Record 16 of Set 5 | durban
# Processing Record 17 of Set 5 | kushmurun
# Processing Record 18 of Set 5 | hofn
# Processing Record 19 of Set 5 | santa maria
# Processing Record 20 of Set 5 | otradnoye
# Processing Record 21 of Set 5 | dikson
# Processing Record 22 of Set 5 | luanda
# Processing Record 23 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 5 | la romana
# Processing Record 25 of Set 5 | uni
# Processing Record 26 of Set 5 | kiama
# Processing Record 27 of Set 5 | chern
# Processing Record 28 of Set 5 | balkhash
# Processing Record 29 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 5 | sept-iles
# Processing Record 31 of Set 5 | banda aceh
# Processing Record 32 of Set 5 | moron
# Processing Record 33 of Set 5 | nouadhibou
# Processing Record 34 of Set 5 | svetlyy
# Processing Record 35 of Set 5 | kalmunai
# Processing Record 36 of Set 5 | naryan-mar
# Processing Record 37 of Set 5 | kandalaksha
# Processing Record 38 of Set 5 | keita
# Processing Record 39 of Set 5 | mae ramat
# Processing Record 40 of Set 5 | bandar maharani
# City not found. Skipping...
# Processing Record 41 of Set 5 | valparaiso
# Processing Record 42 of Set 5 | flinders
# Processing Record 43 of Set 5 | sorland
# Processing Record 44 of Set 5 | talitsa
# Processing Record 45 of Set 5 | poquoson
# Processing Record 46 of Set 5 | ponta do sol
# Processing Record 47 of Set 5 | agboville
# Processing Record 48 of Set 5 | kyra
# Processing Record 49 of Set 5 | nuevo progreso
# Processing Record 50 of Set 5 | bihoro
# Processing Record 1 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 6 | puerto ayora
# Processing Record 3 of Set 6 | banfora
# Processing Record 4 of Set 6 | bria
# Processing Record 5 of Set 6 | shelburne
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | pangody
# Processing Record 8 of Set 6 | ahipara
# Processing Record 9 of Set 6 | bambous virieux
# Processing Record 10 of Set 6 | saint george
# Processing Record 11 of Set 6 | longyearbyen
# Processing Record 12 of Set 6 | lima
# Processing Record 13 of Set 6 | tefe
# Processing Record 14 of Set 6 | chicama
# Processing Record 15 of Set 6 | fort nelson
# Processing Record 16 of Set 6 | musoma
# Processing Record 17 of Set 6 | lavrentiya
# Processing Record 18 of Set 6 | hithadhoo
# Processing Record 19 of Set 6 | paramirim
# Processing Record 20 of Set 6 | alofi
# Processing Record 21 of Set 6 | huejuquilla el alto
# Processing Record 22 of Set 6 | hambantota
# Processing Record 23 of Set 6 | bengkulu
# Processing Record 24 of Set 6 | belfast
# Processing Record 25 of Set 6 | redmond
# Processing Record 26 of Set 6 | marawi
# Processing Record 27 of Set 6 | okha
# Processing Record 28 of Set 6 | khasan
# Processing Record 29 of Set 6 | itarema
# Processing Record 30 of Set 6 | denpasar
# Processing Record 31 of Set 6 | alberton
# Processing Record 32 of Set 6 | simpang
# Processing Record 33 of Set 6 | saint-philippe
# Processing Record 34 of Set 6 | bandarbeyla
# Processing Record 35 of Set 6 | marsa matruh
# Processing Record 36 of Set 6 | bolotnoye
# Processing Record 37 of Set 6 | cururupu
# Processing Record 38 of Set 6 | maksi
# Processing Record 39 of Set 6 | cuxhaven
# Processing Record 40 of Set 6 | bongandanga
# Processing Record 41 of Set 6 | kirakira
# Processing Record 42 of Set 6 | killybegs
# Processing Record 43 of Set 6 | jablah
# Processing Record 44 of Set 6 | karpathos
# Processing Record 45 of Set 6 | port-gentil
# Processing Record 46 of Set 6 | wewak
# Processing Record 47 of Set 6 | laguna
# Processing Record 48 of Set 6 | bauta
# Processing Record 49 of Set 6 | ndjole
# Processing Record 50 of Set 6 | svetlaya
# Processing Record 1 of Set 7 | coquimbo
# Processing Record 2 of Set 7 | san ignacio
# Processing Record 3 of Set 7 | kamenka
# Processing Record 4 of Set 7 | teguldet
# Processing Record 5 of Set 7 | sola
# Processing Record 6 of Set 7 | mandera
# Processing Record 7 of Set 7 | gurupi
# Processing Record 8 of Set 7 | peleduy
# Processing Record 9 of Set 7 | bud
# Processing Record 10 of Set 7 | amalapuram
# Processing Record 11 of Set 7 | safranbolu
# Processing Record 12 of Set 7 | kokopo
# Processing Record 13 of Set 7 | banjar
# Processing Record 14 of Set 7 | huazolotitlan
# City not found. Skipping...
# Processing Record 15 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 7 | katsuura
# Processing Record 17 of Set 7 | ajdabiya
# Processing Record 18 of Set 7 | vardo
# Processing Record 19 of Set 7 | san quintin
# Processing Record 20 of Set 7 | sur
# Processing Record 21 of Set 7 | kahului
# Processing Record 22 of Set 7 | griffith
# Processing Record 23 of Set 7 | talnakh
# Processing Record 24 of Set 7 | poum
# Processing Record 25 of Set 7 | soe
# Processing Record 26 of Set 7 | dakar
# Processing Record 27 of Set 7 | necochea
# Processing Record 28 of Set 7 | pryazha
# Processing Record 29 of Set 7 | lata
# Processing Record 30 of Set 7 | cidreira
# Processing Record 31 of Set 7 | nambucca heads
# Processing Record 32 of Set 7 | darhan
# Processing Record 33 of Set 7 | dunedin
# Processing Record 34 of Set 7 | lakeland
# Processing Record 35 of Set 7 | muhos
# Processing Record 36 of Set 7 | igunga
# Processing Record 37 of Set 7 | aykhal
# Processing Record 38 of Set 7 | gimbi
# Processing Record 39 of Set 7 | aquiraz
# Processing Record 40 of Set 7 | poprad
# Processing Record 41 of Set 7 | namibe
# Processing Record 42 of Set 7 | nalut
# Processing Record 43 of Set 7 | artvin
# Processing Record 44 of Set 7 | general roca
# Processing Record 45 of Set 7 | novikovo
# Processing Record 46 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 47 of Set 7 | zhigansk
# Processing Record 48 of Set 7 | zenzeli
# Processing Record 49 of Set 7 | verkh-usugli
# Processing Record 50 of Set 7 | keti bandar
# Processing Record 1 of Set 8 | villa carlos paz
# Processing Record 2 of Set 8 | nikolskoye
# Processing Record 3 of Set 8 | bailen
# Processing Record 4 of Set 8 | alta floresta
# Processing Record 5 of Set 8 | opuwo
# Processing Record 6 of Set 8 | henties bay
# Processing Record 7 of Set 8 | mayo
# Processing Record 8 of Set 8 | nishihara
# Processing Record 9 of Set 8 | bagdarin
# Processing Record 10 of Set 8 | yinchuan
# Processing Record 11 of Set 8 | mount gambier
# Processing Record 12 of Set 8 | pilar do sul
# Processing Record 13 of Set 8 | dijkot
# Processing Record 14 of Set 8 | hovd
# Processing Record 15 of Set 8 | mehamn
# Processing Record 16 of Set 8 | fujin
# Processing Record 17 of Set 8 | townsville
# Processing Record 18 of Set 8 | suez
# Processing Record 19 of Set 8 | havelock
# Processing Record 20 of Set 8 | bilma
# Processing Record 21 of Set 8 | tonj
# Processing Record 22 of Set 8 | maarianhamina
# Processing Record 23 of Set 8 | acapulco
# Processing Record 24 of Set 8 | ranong
# Processing Record 25 of Set 8 | bima
# Processing Record 26 of Set 8 | kuloy
# Processing Record 27 of Set 8 | borogontsy
# Processing Record 28 of Set 8 | ancud
# Processing Record 29 of Set 8 | udachnyy
# Processing Record 30 of Set 8 | kollo
# Processing Record 31 of Set 8 | saint-pierre
# Processing Record 32 of Set 8 | grand gaube
# Processing Record 33 of Set 8 | touros
# Processing Record 34 of Set 8 | ballina
# Processing Record 35 of Set 8 | brawley
# Processing Record 36 of Set 8 | basco
# Processing Record 37 of Set 8 | aklavik
# Processing Record 38 of Set 8 | labuhan
# Processing Record 39 of Set 8 | balabac
# Processing Record 40 of Set 8 | hailey
# Processing Record 41 of Set 8 | martapura
# Processing Record 42 of Set 8 | urucui
# Processing Record 43 of Set 8 | sabang
# Processing Record 44 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 8 | geraldton
# Processing Record 46 of Set 8 | pedernales
# Processing Record 47 of Set 8 | akyab
# Processing Record 48 of Set 8 | bitung
# Processing Record 49 of Set 8 | ponta delgada
# Processing Record 50 of Set 8 | palmares
# Processing Record 1 of Set 9 | lakatoro
# Processing Record 2 of Set 9 | esmeraldas
# Processing Record 3 of Set 9 | svalyava
# Processing Record 4 of Set 9 | kimbe
# Processing Record 5 of Set 9 | sain alto
# Processing Record 6 of Set 9 | winnemucca
# Processing Record 7 of Set 9 | chara
# Processing Record 8 of Set 9 | tautira
# Processing Record 9 of Set 9 | manta
# Processing Record 10 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 9 | santa ana
# Processing Record 13 of Set 9 | mahebourg
# Processing Record 14 of Set 9 | camacha
# Processing Record 15 of Set 9 | cockburn town
# Processing Record 16 of Set 9 | te anau
# Processing Record 17 of Set 9 | arraial do cabo
# Processing Record 18 of Set 9 | lagos
# Processing Record 19 of Set 9 | petatlan
# Processing Record 20 of Set 9 | shwebo
# Processing Record 21 of Set 9 | melfort
# Processing Record 22 of Set 9 | palu
# Processing Record 23 of Set 9 | olafsvik
# Processing Record 24 of Set 9 | orvieto
# Processing Record 25 of Set 9 | nome
# Processing Record 26 of Set 9 | padang
# Processing Record 27 of Set 9 | walvis bay
# Processing Record 28 of Set 9 | korla
# Processing Record 29 of Set 9 | anderson
# Processing Record 30 of Set 9 | kibiti
# Processing Record 31 of Set 9 | gongzhuling
# Processing Record 32 of Set 9 | north bend
# Processing Record 33 of Set 9 | kovdor
# Processing Record 34 of Set 9 | micheweni
# Processing Record 35 of Set 9 | ambon
# Processing Record 36 of Set 9 | ransang
# Processing Record 37 of Set 9 | guozhen
# Processing Record 38 of Set 9 | beringovskiy
# Processing Record 39 of Set 9 | boffa
# Processing Record 40 of Set 9 | svetlogorsk
# Processing Record 41 of Set 9 | banamba
# Processing Record 42 of Set 9 | praia
# Processing Record 43 of Set 9 | cayenne
# Processing Record 44 of Set 9 | tazovskiy
# Processing Record 45 of Set 9 | bathsheba
# Processing Record 46 of Set 9 | sao jose da coroa grande
# Processing Record 47 of Set 9 | katangli
# Processing Record 48 of Set 9 | pangnirtung
# Processing Record 49 of Set 9 | vestmannaeyjar
# Processing Record 50 of Set 9 | witu
# Processing Record 1 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 10 | guaraniacu
# Processing Record 3 of Set 10 | weston
# Processing Record 4 of Set 10 | port macquarie
# Processing Record 5 of Set 10 | carbonia
# Processing Record 6 of Set 10 | westport
# Processing Record 7 of Set 10 | vysokogornyy
# Processing Record 8 of Set 10 | lar
# Processing Record 9 of Set 10 | the valley
# Processing Record 10 of Set 10 | conde
# Processing Record 11 of Set 10 | bairiki
# Processing Record 12 of Set 10 | ihosy
# Processing Record 13 of Set 10 | muyezerskiy
# Processing Record 14 of Set 10 | vazante
# Processing Record 15 of Set 10 | adrar
# Processing Record 16 of Set 10 | stokmarknes
# Processing Record 17 of Set 10 | palencia
# Processing Record 18 of Set 10 | surin
# Processing Record 19 of Set 10 | dujuma
# City not found. Skipping...
# Processing Record 20 of Set 10 | ilhabela
# Processing Record 21 of Set 10 | redwater
# Processing Record 22 of Set 10 | buin
# Processing Record 23 of Set 10 | yerbogachen
# Processing Record 24 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 25 of Set 10 | ayagoz
# Processing Record 26 of Set 10 | mabaruma
# Processing Record 27 of Set 10 | tongling
# Processing Record 28 of Set 10 | sinnamary
# Processing Record 29 of Set 10 | bahia honda
# Processing Record 30 of Set 10 | nara
# Processing Record 31 of Set 10 | omboue
# Processing Record 32 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 33 of Set 10 | deputatskiy
# Processing Record 34 of Set 10 | rio bananal
# Processing Record 35 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 36 of Set 10 | irece
# Processing Record 37 of Set 10 | menongue
# Processing Record 38 of Set 10 | salalah
# Processing Record 39 of Set 10 | ilebo
# Processing Record 40 of Set 10 | kanye
# Processing Record 41 of Set 10 | la ronge
# Processing Record 42 of Set 10 | portland
# Processing Record 43 of Set 10 | imbituba
# Processing Record 44 of Set 10 | jagdalpur
# Processing Record 45 of Set 10 | pacific grove
# Processing Record 46 of Set 10 | kununurra
# Processing Record 47 of Set 10 | distraccion
# Processing Record 48 of Set 10 | zuenoula
# Processing Record 49 of Set 10 | conakry
# Processing Record 50 of Set 10 | provideniya
# Processing Record 1 of Set 11 | finschhafen
# Processing Record 2 of Set 11 | zwedru
# Processing Record 3 of Set 11 | kogon
# Processing Record 4 of Set 11 | abu dhabi
# Processing Record 5 of Set 11 | harlingen
# Processing Record 6 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 11 | oranjemund
# Processing Record 8 of Set 11 | sonoita
# Processing Record 9 of Set 11 | southbridge
# Processing Record 10 of Set 11 | tornio
# Processing Record 11 of Set 11 | inhambane
# Processing Record 12 of Set 11 | shimoda
# Processing Record 13 of Set 11 | san jeronimo de tunan
# City not found. Skipping...
# Processing Record 14 of Set 11 | polyarnyy
# Processing Record 15 of Set 11 | mareeba
# Processing Record 16 of Set 11 | puerto madero
# Processing Record 17 of Set 11 | dali
# Processing Record 18 of Set 11 | kattivakkam
# Processing Record 19 of Set 11 | gat
# Processing Record 20 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 11 | pata
# Processing Record 22 of Set 11 | codo
# Processing Record 23 of Set 11 | srandakan
# Processing Record 24 of Set 11 | bajil
# Processing Record 25 of Set 11 | kissamos
# Processing Record 26 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 11 | beyneu
# Processing Record 28 of Set 11 | cabedelo
# Processing Record 29 of Set 11 | novougolnyy
# City not found. Skipping...
# Processing Record 30 of Set 11 | besikduzu
# Processing Record 31 of Set 11 | ahlat
# Processing Record 32 of Set 11 | fethiye
# Processing Record 33 of Set 11 | waipawa
# Processing Record 34 of Set 11 | kokstad
# Processing Record 35 of Set 11 | boyolangu
# Processing Record 36 of Set 11 | oistins
# Processing Record 37 of Set 11 | hokitika
# Processing Record 38 of Set 11 | lakes entrance
# Processing Record 39 of Set 11 | avera
# Processing Record 40 of Set 11 | perth
# Processing Record 41 of Set 11 | agirish
# Processing Record 42 of Set 11 | rawson
# Processing Record 43 of Set 11 | severo-kurilsk
# Processing Record 44 of Set 11 | kavaratti
# Processing Record 45 of Set 11 | karratha
# Processing Record 46 of Set 11 | milove
# Processing Record 47 of Set 11 | aksu
# Processing Record 48 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 11 | apango
# Processing Record 50 of Set 11 | big spring
# Processing Record 1 of Set 12 | kathu
# Processing Record 2 of Set 12 | medea
# Processing Record 3 of Set 12 | santa cruz cabralia
# Processing Record 4 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 12 | werdau
# Processing Record 6 of Set 12 | pastavy
# Processing Record 7 of Set 12 | utena
# Processing Record 8 of Set 12 | sakassou
# Processing Record 9 of Set 12 | humaita
# Processing Record 10 of Set 12 | kargil
# Processing Record 11 of Set 12 | esil
# Processing Record 12 of Set 12 | lompoc
# Processing Record 13 of Set 12 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 14 of Set 12 | diffa
# Processing Record 15 of Set 12 | taikang
# Processing Record 16 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 12 | owando
# Processing Record 18 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 12 | buldana
# Processing Record 20 of Set 12 | melendugno
# Processing Record 21 of Set 12 | gizo
# Processing Record 22 of Set 12 | sigli
# Processing Record 23 of Set 12 | sinfra
# Processing Record 24 of Set 12 | beloha
# Processing Record 25 of Set 12 | elizabeth city
# Processing Record 26 of Set 12 | candelaria
# Processing Record 27 of Set 12 | minab
# Processing Record 28 of Set 12 | luoyang
# Processing Record 29 of Set 12 | orotukan
# Processing Record 30 of Set 12 | oktyabrskoye
# Processing Record 31 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 32 of Set 12 | margate
# Processing Record 33 of Set 12 | luziania
# Processing Record 34 of Set 12 | la primavera
# Processing Record 35 of Set 12 | kungurtug
# Processing Record 36 of Set 12 | merritt
# Processing Record 37 of Set 12 | hinesville
# Processing Record 38 of Set 12 | fairbanks
# Processing Record 39 of Set 12 | yeniseysk
# Processing Record 40 of Set 12 | kovur
# Processing Record 41 of Set 12 | estelle
# Processing Record 42 of Set 12 | asau
# Processing Record 43 of Set 12 | ust-kuyga
# Processing Record 44 of Set 12 | riyadh
# Processing Record 45 of Set 12 | kloulklubed
# Processing Record 46 of Set 12 | juneau
# Processing Record 47 of Set 12 | abonnema
# Processing Record 48 of Set 12 | pindiga
# Processing Record 49 of Set 12 | oytal
# Processing Record 50 of Set 12 | wajima
# Processing Record 1 of Set 13 | longhua
# Processing Record 2 of Set 13 | huarmey
# Processing Record 3 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 13 | rajapalaiyam
# Processing Record 5 of Set 13 | codrington
# Processing Record 6 of Set 13 | sattahip
# Processing Record 7 of Set 13 | sile
# Processing Record 8 of Set 13 | veraval
# Processing Record 9 of Set 13 | isangel
# Processing Record 10 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 11 of Set 13 | roros
# Processing Record 12 of Set 13 | kokoda
# Processing Record 13 of Set 13 | siukh
# Processing Record 14 of Set 13 | chilliwack
# Processing Record 15 of Set 13 | derzhavinsk
# Processing Record 16 of Set 13 | aswan
# Processing Record 17 of Set 13 | mopti
# Processing Record 18 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 13 | brigantine
# Processing Record 20 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 21 of Set 13 | izumo
# Processing Record 22 of Set 13 | port hedland
# Processing Record 23 of Set 13 | praia da vitoria
# Processing Record 24 of Set 13 | przhevalskoye
# Processing Record 25 of Set 13 | olinda
# Processing Record 26 of Set 13 | hopkinton
# Processing Record 27 of Set 13 | shirhatti
# Processing Record 28 of Set 13 | khorol
# Processing Record 29 of Set 13 | malini
# Processing Record 30 of Set 13 | yumen
# Processing Record 31 of Set 13 | rockport
# Processing Record 32 of Set 13 | egvekinot
# Processing Record 33 of Set 13 | lebedinyy
# Processing Record 34 of Set 13 | san vicente
# Processing Record 35 of Set 13 | nisia floresta
# Processing Record 36 of Set 13 | makinsk
# Processing Record 37 of Set 13 | yangliuqing
# Processing Record 38 of Set 13 | tabas
# Processing Record 39 of Set 13 | santa cruz
# Processing Record 40 of Set 13 | navapur
# City not found. Skipping...
# Processing Record 41 of Set 13 | jieshi
# Processing Record 42 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 43 of Set 13 | dalnerechensk
# Processing Record 44 of Set 13 | talara
# Processing Record 45 of Set 13 | umea
# Processing Record 46 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 13 | san jose
# Processing Record 48 of Set 13 | maple creek
# Processing Record 49 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 50 of Set 13 | ladario
# Processing Record 1 of Set 14 | sampang
# Processing Record 2 of Set 14 | arlit
# Processing Record 3 of Set 14 | tselinnoye
# Processing Record 4 of Set 14 | yenagoa
# Processing Record 5 of Set 14 | bonfim
# Processing Record 6 of Set 14 | torrington
# Processing Record 7 of Set 14 | levelland
# Processing Record 8 of Set 14 | corning
# Processing Record 9 of Set 14 | krasnyy oktyabr
# Processing Record 10 of Set 14 | cangucu
# Processing Record 11 of Set 14 | aranos
# Processing Record 12 of Set 14 | kangaba
# Processing Record 13 of Set 14 | songea
# Processing Record 14 of Set 14 | linxia
# Processing Record 15 of Set 14 | kedrovyy
# Processing Record 16 of Set 14 | vallenar
# Processing Record 17 of Set 14 | penzance
# Processing Record 18 of Set 14 | jackson
# Processing Record 19 of Set 14 | karakol
# Processing Record 20 of Set 14 | merauke
# Processing Record 21 of Set 14 | freeport
# Processing Record 22 of Set 14 | oga
# Processing Record 23 of Set 14 | eyl
# Processing Record 24 of Set 14 | burica
# City not found. Skipping...
# Processing Record 25 of Set 14 | yanam
# Processing Record 26 of Set 14 | vila franca do campo
# Processing Record 27 of Set 14 | safaga
# Processing Record 28 of Set 14 | mackay
# Processing Record 29 of Set 14 | kawhia
# Processing Record 30 of Set 14 | canico
# Processing Record 31 of Set 14 | urusha
# Processing Record 32 of Set 14 | tukrah
# Processing Record 33 of Set 14 | biak
# Processing Record 34 of Set 14 | taltal
# Processing Record 35 of Set 14 | haukipudas
# Processing Record 36 of Set 14 | mayumba
# Processing Record 37 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 38 of Set 14 | beidao
# Processing Record 39 of Set 14 | tyler
# Processing Record 40 of Set 14 | sumenep
# Processing Record 41 of Set 14 | rudbar
# Processing Record 42 of Set 14 | tamandare
# Processing Record 43 of Set 14 | dargaville
# Processing Record 44 of Set 14 | matara
# Processing Record 45 of Set 14 | am timan
# Processing Record 46 of Set 14 | araouane
# Processing Record 47 of Set 14 | belaya gora
# Processing Record 48 of Set 14 | maniitsoq
# Processing Record 49 of Set 14 | belyy yar
# Processing Record 50 of Set 14 | nacala
# Processing Record 1 of Set 15 | anadyr
# Processing Record 2 of Set 15 | santa catarina de tepehuanes
# Processing Record 3 of Set 15 | guayaquil
# Processing Record 4 of Set 15 | saint-leu
# Processing Record 5 of Set 15 | santa rosa
# Processing Record 6 of Set 15 | eregli
# Processing Record 7 of Set 15 | mpanda
# Processing Record 8 of Set 15 | beverungen
# Processing Record 9 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 15 | coihaique
# Processing Record 11 of Set 15 | mao
# Processing Record 12 of Set 15 | lamu
# Processing Record 13 of Set 15 | bosaso
# Processing Record 14 of Set 15 | luderitz
# Processing Record 15 of Set 15 | ndele
# Processing Record 16 of Set 15 | wiarton
# Processing Record 17 of Set 15 | vermilion
# Processing Record 18 of Set 15 | birao
# Processing Record 19 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 15 | mizdah
# Processing Record 21 of Set 15 | lieksa
# Processing Record 22 of Set 15 | jacareacanga
# Processing Record 23 of Set 15 | esna
# Processing Record 24 of Set 15 | dromolaxia
# Processing Record 25 of Set 15 | chulym
# Processing Record 26 of Set 15 | tabou
# Processing Record 27 of Set 15 | popondetta
# Processing Record 28 of Set 15 | auki
# Processing Record 29 of Set 15 | neya
# Processing Record 30 of Set 15 | lingao
# Processing Record 31 of Set 15 | hamilton
# Processing Record 32 of Set 15 | ampanihy
# Processing Record 33 of Set 15 | harper
# Processing Record 34 of Set 15 | abja-paluoja
# Processing Record 35 of Set 15 | do gonbadan
# Processing Record 36 of Set 15 | tawang
# Processing Record 37 of Set 15 | bafra
# Processing Record 38 of Set 15 | kannangad
# Processing Record 39 of Set 15 | ndioum
# Processing Record 40 of Set 15 | umm lajj
# Processing Record 41 of Set 15 | dukat
# Processing Record 42 of Set 15 | leshukonskoye
# Processing Record 43 of Set 15 | sidi ali
# Processing Record 44 of Set 15 | goderich
# Processing Record 45 of Set 15 | mossendjo
# Processing Record 46 of Set 15 | khabary
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 682

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Iquique -20.22  -70.14     62.60        72          90
# 1             Avarua -21.21 -159.78     78.80        83          25
# 2            Qaanaaq  77.48  -69.36     11.07        78           0
# 3     Ribeira Grande  38.52  -28.70     69.78        81          87
# 4  Novokruchininskiy  51.78  113.77     37.40        82          40
# 5             Sorong  -0.88  131.25     78.78        87         100
# 6        Clyde River  70.47  -68.59     28.40       100          90
# 7             Noumea -22.28  166.46     73.00        60          90
# 8          Pestravka  52.41   49.96     52.93        57          52
# 9    Varzea Da Palma -17.60  -44.73     83.16        31          42
#
#    Wind Speed Country Current Description                 Date
# 0       17.22      CL     overcast clouds  2020-09-30 22:35:12
# 1       18.34      CK    scattered clouds  2020-09-30 22:39:16
# 2        6.96      GL           clear sky  2020-09-30 22:38:51
# 3       10.27      PT     overcast clouds  2020-09-30 22:34:50
# 4        4.90      RU    scattered clouds  2020-09-30 22:39:16
# 5        8.84      ID     overcast clouds  2020-09-30 22:39:17
# 6       12.75      CA          light snow  2020-09-30 22:39:17
# 7        2.24      NC     overcast clouds  2020-09-30 22:39:17
# 8        5.44      RU       broken clouds  2020-09-30 22:39:17
# 9        6.55      BR    scattered clouds  2020-09-30 22:37:22

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Iquique      CL -20.22  -70.14     62.60        72          90
# 1             Avarua      CK -21.21 -159.78     78.80        83          25
# 2            Qaanaaq      GL  77.48  -69.36     11.07        78           0
# 3     Ribeira Grande      PT  38.52  -28.70     69.78        81          87
# 4  Novokruchininskiy      RU  51.78  113.77     37.40        82          40
# 5             Sorong      ID  -0.88  131.25     78.78        87         100
# 6        Clyde River      CA  70.47  -68.59     28.40       100          90
# 7             Noumea      NC -22.28  166.46     73.00        60          90
# 8          Pestravka      RU  52.41   49.96     52.93        57          52
# 9    Varzea Da Palma      BR -17.60  -44.73     83.16        31          42
#
#    Wind Speed Current Description
# 0       17.22     overcast clouds
# 1       18.34    scattered clouds
# 2        6.96           clear sky
# 3       10.27     overcast clouds
# 4        4.90    scattered clouds
# 5        8.84     overcast clouds
# 6       12.75          light snow
# 7        2.24     overcast clouds
# 8        5.44       broken clouds
# 9        6.55    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
